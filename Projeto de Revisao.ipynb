# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Apreensão de Menores na Baixada Fluminense

# %%
ocorrencias = pd.read_csv('https://www.ispdados.rj.gov.br/Arquivos/BaseDPEvolucaoMensalCisp.csv', sep= ';', encoding= 'latin1')
ocorrencias
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp                 munic    mcirc  \
# 0         1    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 1         4    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 2         5    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 3         6    1  2003  2003m01     1     1        Rio de Janeiro  3304557
# 4         7    1  2003  2003m01     1     1        Rio de Janeiro  3304557
# ...     ...  ...   ...      ...   ...   ...                   ...      ...
# 36624   159    8  2025  2025m08    35     4  Cachoeiras de Macacu  3300803
# 36625   165    8  2025  2025m08    33     5           Mangaratiba  3302601
# 36626   166    8  2025  2025m08    33     5        Angra dos Reis  3300100
# 36627   167    8  2025  2025m08    43     5                Paraty  3303807
# 36628   168    8  2025  2025m08    28     5             Rio Claro  3304409
#
#          regiao  hom_doloso  ...   cmp  cmba  ameaca  pessoas_desaparecidas  \
# 0       Capital           0  ...   NaN   NaN      21                      2
# 1       Capital           3  ...   NaN   NaN      15                      6
# 2       Capital           3  ...   NaN   NaN      47                      2
# 3       Capital           6  ...   NaN   NaN      26                      2
# 4       Capital           4  ...   NaN   NaN      10                      1
# ...         ...         ...  ...   ...   ...     ...                    ...
# 36624  Interior           1  ...   5.0   0.0      16                      0
# 36625  Interior           0  ...   5.0   0.0      21                      2
# 36626  Interior           3  ...  11.0   3.0      63                      8
# 36627  Interior           0  ...   3.0   0.0      13                      2
# 36628  Interior           1  ...   1.0   0.0       5                      0
#
#        encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 0                     0                0                          0
# 1                     0                1                          0
# 2                     1                0                          0
# 3                     1                0                          0
# 4                     3                0                          0
# ...                 ...              ...                        ...
# 36624                 0                0                          0
# 36625                 0                0                          0
# 36626                 0                0                          0
# 36627                 0                1                          0
# 36628                 0                0                          0
#
#        pol_civis_mortos_serv  registro_ocorrencias  fase
# 0                          0                   578     3
# 1                          0                   441     3
# 2                          0                   637     3
# 3                          0                   473     3
# 4                          0                   147     3
# ...                      ...                   ...   ...
# 36624                      0                   148     2
# 36625                      0                   179     2
# 36626                      0                   595     2
# 36627                      0                   234     2
# 36628                      0                    50     2
#
# [36629 rows x 63 columns]

# %%
ocorrencias_baixada = ocorrencias.loc[ocorrencias['regiao'] == 'Baixada Fluminense']
ocorrencias_baixada.sort_values(by="regiao")
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp         munic    mcirc  \
# 38       48    1  2003  2003m01    24     3    Seropédica  3305554
# 24477    57    4  2018  2018m04    20     3     Nilópolis  3303203
# 24476    56    4  2018  2018m04    20     3   Nova Iguaçu  3303500
# 24475    55    4  2018  2018m04    24     3     Queimados  3304144
# 24474    54    4  2018  2018m04    39     3  Belford Roxo  3300456
# ...     ...  ...   ...      ...   ...   ...           ...      ...
# 12268    52   11  2010  2010m11    20     3   Nova Iguaçu  3303500
# 12267    51   11  2010  2010m11    24     3     Paracambi  3303609
# 12266    50   11  2010  2010m11    24     3       Itaguaí  3302007
# 12273    57   11  2010  2010m11    20     3     Nilópolis  3303203
# 36551    67    8  2025  2025m08    34     3    Guapimirim  3301850
#
#                    regiao  hom_doloso  ...   cmp  cmba  ameaca  \
# 38     Baixada Fluminense           4  ...   NaN   NaN      28
# 24477  Baixada Fluminense           1  ...   4.0   0.0      69
# 24476  Baixada Fluminense          15  ...   2.0   1.0      78
# 24475  Baixada Fluminense           8  ...  24.0   2.0      47
# 24474  Baixada Fluminense          17  ...  21.0   1.0      85
# ...                   ...         ...  ...   ...   ...     ...
# 12268  Baixada Fluminense           2  ...  16.0   0.0     109
# 12267  Baixada Fluminense           0  ...   3.0   0.0      25
# 12266  Baixada Fluminense           6  ...   8.0   1.0      54
# 12273  Baixada Fluminense           8  ...   1.0   0.0      86
# 36551  Baixada Fluminense           1  ...  10.0   0.0      26
#
#        pessoas_desaparecidas  encontro_cadaver  encontro_ossada  \
# 38                         0                 1                0
# 24477                      4                 2                0
# 24476                      7                 0                0
# 24475                      3                 1                0
# 24474                      9                 0                0
# ...                      ...               ...              ...
# 12268                      4                 0                0
# 12267                      1                 0                0
# 12266                      2                 0                0
# 12273                      7                 0                0
# 36551                      1                 0                0
#
#        pol_militares_mortos_serv  pol_civis_mortos_serv  registro_ocorrencias  \
# 38                             0                      0                   139
# 24477                          0                      0                   654
# 24476                          0                      0                   800
# 24475                          0                      0                   406
# 24474                          0                      0                  1431
# ...                          ...                    ...                   ...
# 12268                          0                      0                   911
# 12267                          0                      0                   104
# 12266                          0                      0                   400
# 12273                          0                      0                   525
# 36551                          0                      0                   266
#
#        fase
# 38        3
# 24477     3
# 24476     3
# 24475     3
# 24474     3
# ...     ...
# 12268     3
# 12267     3
# 12266     3
# 12273     3
# 36551     2
#
# [5060 rows x 63 columns]

# %%
aaapai = ocorrencias_baixada.groupby('munic')['aaapai'].sum().reset_index()   
aaapai
# Out:
#                  munic  aaapai
# 0         Belford Roxo  2584.0
# 1      Duque de Caxias  6233.0
# 2           Guapimirim   213.0
# 3              Itaguaí   881.0
# 4               Japeri   402.0
# 5                 Magé  1251.0
# 6      Magé;Guapimirim   126.0
# 7             Mesquita  1218.0
# 8            Nilópolis   693.0
# 9          Nova Iguaçu  4098.0
# 10           Paracambi   366.0
# 11           Queimados   573.0
# 12    Queimados;Japeri     0.0
# 13          Seropédica   309.0
# 14  São João de Meriti  2953.0

# %%
aaapai_array = np.array(aaapai['aaapai'])

# %%
mediana = np.median(aaapai_array)
media = np.mean(aaapai_array)
q1 = np.percentile(aaapai_array, 25)
q2 = np.percentile(aaapai_array, 50)
q3 = np.percentile (aaapai_array, 75)
distancia = (media - mediana)/mediana
iqr = q3 - q1
limite_superior = q3 + (1.5 * iqr)
limite_inferior = q1 - (1.5 * iqr)
print(f'Média: {media}')
print(f'Mediana: {mediana}')
print(f'Distância: {round(distancia*100,2)} %')
print(f'Limite Superior: {limite_superior}')
print(f'Limite Inferior: {limite_inferior}')
print(f'Q3: {q3}')
# Out:
# Média: 1460.0
# Mediana: 693.0
# Distância: 110.68 %
# Limite Superior: 4287.5
# Limite Inferior: -2032.5
# Q3: 1917.5

# %%
aaapai_outliers = aaapai.loc[aaapai['aaapai'] >= limite_superior]
aaapai_outliers.sort_values(by="aaapai")
# Out:
#              munic  aaapai
# 1  Duque de Caxias  6233.0

# %%
aaapai_q3 = aaapai.loc[aaapai['aaapai'] >= q3]
aaapai_q3.sort_values(by="aaapai", ascending=False)
# Out:
#                  munic  aaapai
# 1      Duque de Caxias  6233.0
# 9          Nova Iguaçu  4098.0
# 14  São João de Meriti  2953.0
# 0         Belford Roxo  2584.0

# %%
aaapai_outliers.to_csv('aaapai_outliers', index=False)

# %%
aaapai_q3.to_csv('aaapai_q3', index=False)

# %% [markdown]
# 3. Estelionato na Capital

# %%
ocorrencias_capital = ocorrencias.loc[ocorrencias['regiao'] == 'Capital']
ocorrencias_capital.sort_values(by="regiao")
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 0         1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 24320    35    3  2018  2018m03    40     2  Rio de Janeiro  3304557  Capital
# 24321    36    3  2018  2018m03    27     2  Rio de Janeiro  3304557  Capital
# 24322    37    3  2018  2018m03    17     1  Rio de Janeiro  3304557  Capital
# 24323    38    3  2018  2018m03    16     1  Rio de Janeiro  3304557  Capital
# ...     ...  ...   ...      ...   ...   ...             ...      ...      ...
# 12128    41   10  2010  2010m10    18     2  Rio de Janeiro  3304557  Capital
# 12129    42   10  2010  2010m10    31     2  Rio de Janeiro  3304557  Capital
# 12130    43   10  2010  2010m10    39     2  Rio de Janeiro  3304557  Capital
# 12122    35   10  2010  2010m10    39     2  Rio de Janeiro  3304557  Capital
# 36532    44    8  2025  2025m08     3     1  Rio de Janeiro  3304557  Capital
#
#        hom_doloso  ...   cmp  cmba  ameaca  pessoas_desaparecidas  \
# 0               0  ...   NaN   NaN      21                      2
# 24320           7  ...  33.0   2.0     167                     23
# 24321           8  ...  16.0   0.0     104                     16
# 24322           7  ...   9.0   0.0      44                     11
# 24323           5  ...   3.0   2.0      60                      8
# ...           ...  ...   ...   ...     ...                    ...
# 12128           1  ...   5.0   0.0      70                      0
# 12129           2  ...   5.0   0.0      69                      2
# 12130           2  ...   5.0   0.0      61                      4
# 12122          13  ...  11.0   1.0     317                     21
# 36532           1  ...  13.0   0.0      43                      5
#
#        encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 0                     0                0                          0
# 24320                 1                0                          0
# 24321                 1                0                          0
# 24322                 0                0                          0
# 24323                 0                0                          0
# ...                 ...              ...                        ...
# 12128                 0                0                          0
# 12129                 0                0                          0
# 12130                 0                0                          0
# 12122                 0                0                          0
# 36532                 1                0                          0
#
#        pol_civis_mortos_serv  registro_ocorrencias  fase
# 0                          0                   578     3
# 24320                      0                  1566     3
# 24321                      0                   896     3
# 24322                      0                   673     3
# 24323                      0                   867     3
# ...                      ...                   ...   ...
# 12128                      0                   607     3
# 12129                      0                   461     3
# 12130                      0                   314     3
# 12122                      0                  1902     3
# 36532                      0                   808     2
#
# [10992 rows x 63 columns]

# %%
estelionato = ocorrencias_capital.groupby('cisp')['estelionato'].sum().reset_index()   
estelionato
# Out:
#     cisp  estelionato
# 0      1        27293
# 1      4         6918
# 2      5        21417
# 3      6         7226
# 4      7         2182
# 5      9        17092
# 6     10        19249
# 7     11         1293
# 8     12        21174
# 9     13        11509
# 10    14        18586
# 11    15        10409
# 12    16        41003
# 13    17         6998
# 14    18        10130
# 15    19        20340
# 16    20        13490
# 17    21        17909
# 18    22        13293
# 19    23        14311
# 20    24         8637
# 21    25         7523
# 22    26         8369
# 23    27        13830
# 24    28        10632
# 25    29        17796
# 26    30         8875
# 27    31         6443
# 28    32        32570
# 29    33        15389
# 30    34        23101
# 31    35        38234
# 32    36        15234
# 33    37        15427
# 34    38        10100
# 35    39         8129
# 36    40         6726
# 37    41        12936
# 38    42        19272
# 39    43         6065
# 40    44         6661
# 41    45           98

# %%
estelionato_array = np.array(estelionato['estelionato'])

# %%
mediana_e = np.median(estelionato_array)
media_e = np.mean(estelionato_array)
q1_e = np.percentile(estelionato_array, 25)
q2_e = np.percentile(estelionato_array, 50)
q3_e = np.percentile (estelionato_array, 75)
distancia_e = (media_e - mediana_e)/mediana_e
iqr_e = q3_e - q1_e
limite_superior_e = q3_e + (1.5 * iqr_e)
limite_inferior_e = q1_e - (1.5 * iqr_e)
print(f'Média: {media_e}')
print(f'Mediana: {mediana_e}')
print(f'Distância: {round(distancia_e*100,2)} %')
print(f'Limite Superior: {limite_superior_e}')
print(f'Limite Inferior: {limite_inferior_e}')
print(f'Q3: {q3_e}')
# Out:
# Média: 14139.738095238095
# Mediana: 13114.5
# Distância: 7.82 %
# Limite Superior: 34530.125
# Limite Inferior: -8438.875
# Q3: 18416.75

# %%
estelionato_q3 = estelionato.loc[estelionato['estelionato'] >= q3_e]
estelionato_q3.sort_values(by="estelionato", ascending=False)
# Out:
#     cisp  estelionato
# 12    16        41003
# 31    35        38234
# 28    32        32570
# 0      1        27293
# 30    34        23101
# 2      5        21417
# 8     12        21174
# 15    19        20340
# 38    42        19272
# 6     10        19249
# 10    14        18586

# %%
estelionato_q3.to_csv('estelionato_q3', index=False)

# %% [markdown]
# 4. Crimes Violentos na Região dos Lagos

# %%
crimes = pd.read_csv('https://www.ispdados.rj.gov.br/Arquivos/BaseMunicipioMensal.csv', sep= ';', encoding= 'latin1')
crimes
# Out:
#        fmun_cod                fmun   ano  mes  mes_ano    regiao  hom_doloso  \
# 0       3300100      Angra dos Reis  2014    1  2014m01  Interior          11
# 1       3300159             Aperibé  2014    1  2014m01  Interior           0
# 2       3300209            Araruama  2014    1  2014m01  Interior           2
# 3       3300225               Areal  2014    1  2014m01  Interior           0
# 4       3300233  Armação dos Búzios  2014    1  2014m01  Interior           2
# ...         ...                 ...   ...  ...      ...       ...         ...
# 12876   3306008           Três Rios  2025    8  2025m08  Interior           1
# 12877   3306107             Valença  2025    8  2025m08  Interior           0
# 12878   3306156           Varre-Sai  2025    8  2025m08  Interior           1
# 12879   3306206           Vassouras  2025    8  2025m08  Interior           0
# 12880   3306305       Volta Redonda  2025    8  2025m08  Interior           6
#
#        lesao_corp_morte  latrocinio  cvli  ...  cmp  cmba  ameaca  \
# 0                     0           0    11  ...    8     0      98
# 1                     0           0     0  ...    0     0       0
# 2                     0           0     2  ...    5     0      91
# 3                     0           0     0  ...    0     0       0
# 4                     0           0     2  ...    3     2      46
# ...                 ...         ...   ...  ...  ...   ...     ...
# 12876                 0           0     1  ...   19     2      55
# 12877                 0           0     0  ...    6     1      48
# 12878                 0           0     1  ...    0     0       7
# 12879                 0           0     0  ...    1     0      27
# 12880                 0           0     6  ...   26     2     157
#
#        pessoas_desaparecidas  encontro_cadaver  encontro_ossada  \
# 0                         13                 3                0
# 1                          0                 0                0
# 2                         10                 1                0
# 3                          0                 0                0
# 4                          0                 0                0
# ...                      ...               ...              ...
# 12876                      1                 0                0
# 12877                      1                 1                0
# 12878                      0                 0                0
# 12879                      0                 0                0
# 12880                      7                 0                0
#
#        pol_militares_mortos_serv  pol_civis_mortos_serv  registro_ocorrencias  \
# 0                              0                      0                   561
# 1                              0                      0                     0
# 2                              0                      0                   480
# 3                              0                      0                     0
# 4                              0                      0                   309
# ...                          ...                    ...                   ...
# 12876                          0                      0                   514
# 12877                          0                      0                   206
# 12878                          0                      0                    33
# 12879                          0                      0                   121
# 12880                          0                      0                  1456
#
#        fase
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
# ...     ...
# 12876     2
# 12877     2
# 12878     2
# 12879     2
# 12880     2
#
# [12881 rows x 60 columns]

# %%
regiao_lagos = ['Rio das Ostras', 'Armação dos Búzios', 'Arraial do Cabo', 'Cabo Frio', 'Iguaba Grande', 'São Pedro da Aldeia', 'Casemiro de Abreu',
'Silva Jardim', 'Araruama', 'Saquarema']
crimes_violentos = crimes.loc[(crimes['fmun'].isin(regiao_lagos))] 
crimes_violentos
# Out:
#        fmun_cod                 fmun   ano  mes  mes_ano    regiao  \
# 2       3300209             Araruama  2014    1  2014m01  Interior
# 4       3300233   Armação dos Búzios  2014    1  2014m01  Interior
# 5       3300258      Arraial do Cabo  2014    1  2014m01  Interior
# 11      3300704            Cabo Frio  2014    1  2014m01  Interior
# 27      3301876        Iguaba Grande  2014    1  2014m01  Interior
# ...         ...                  ...   ...  ...      ...       ...
# 12816   3301876        Iguaba Grande  2025    8  2025m08  Interior
# 12855   3304524       Rio das Ostras  2025    8  2025m08  Interior
# 12866   3305208  São Pedro da Aldeia  2025    8  2025m08  Interior
# 12869   3305505            Saquarema  2025    8  2025m08  Interior
# 12871   3305604         Silva Jardim  2025    8  2025m08  Interior
#
#        hom_doloso  lesao_corp_morte  latrocinio  cvli  ...  cmp  cmba  ameaca  \
# 2               2                 0           0     2  ...    5     0      91
# 4               2                 0           0     2  ...    3     2      46
# 5               0                 0           0     0  ...    1     0      26
# 11              9                 0           0     9  ...    8     0     121
# 27              0                 0           0     0  ...    1     0      19
# ...           ...               ...         ...   ...  ...  ...   ...     ...
# 12816           0                 0           0     0  ...    3     0      18
# 12855           1                 0           0     1  ...   13     3      50
# 12866           3                 0           0     3  ...   10     1      33
# 12869           3                 0           0     3  ...   15     0      80
# 12871           0                 0           0     0  ...    2     0      13
#
#        pessoas_desaparecidas  encontro_cadaver  encontro_ossada  \
# 2                         10                 1                0
# 4                          0                 0                0
# 5                          0                 0                0
# 11                         7                 3                0
# 27                         0                 0                0
# ...                      ...               ...              ...
# 12816                      1                 0                0
# 12855                      8                 0                0
# 12866                      1                 0                0
# 12869                      2                 0                0
# 12871                      0                 0                0
#
#        pol_militares_mortos_serv  pol_civis_mortos_serv  registro_ocorrencias  \
# 2                              0                      0                   480
# 4                              0                      0                   309
# 5                              0                      0                   176
# 11                             0                      0                  1105
# 27                             0                      0                   126
# ...                          ...                    ...                   ...
# 12816                          0                      0                   157
# 12855                          0                      0                   724
# 12866                          0                      0                   321
# 12869                          0                      0                   858
# 12871                          0                      0                    68
#
#        fase
# 2         3
# 4         3
# 5         3
# 11        3
# 27        3
# ...     ...
# 12816     2
# 12855     2
# 12866     2
# 12869     2
# 12871     2
#
# [1260 rows x 60 columns]

# %%
crimes_violentos['crimes_violentos'] = crimes_violentos['hom_doloso'] + crimes_violentos['lesao_corp_morte'] + crimes_violentos['latrocinio'] + crimes_violentos['cvli'] + crimes_violentos['hom_por_interv_policial'] + crimes_violentos['letalidade_violenta'] + crimes_violentos['tentat_hom'] + crimes_violentos['lesao_corp_dolosa'] + crimes_violentos['estupro']
crimes_violentos
# Out:
# C:\Users\Steffani.Oliveira\AppData\Local\Temp\ipykernel_12592\1088963296.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crimes_violentos['crimes_violentos'] = crimes_violentos['hom_doloso'] + crimes_violentos['lesao_corp_morte'] + crimes_violentos['latrocinio'] + crimes_violentos['cvli'] + crimes_violentos['hom_por_interv_policial'] + crimes_violentos['letalidade_violenta'] + crimes_violentos['tentat_hom'] + crimes_violentos['lesao_corp_dolosa'] + crimes_violentos['estupro']
#        fmun_cod                 fmun   ano  mes  mes_ano    regiao  \
# 2       3300209             Araruama  2014    1  2014m01  Interior
# 4       3300233   Armação dos Búzios  2014    1  2014m01  Interior
# 5       3300258      Arraial do Cabo  2014    1  2014m01  Interior
# 11      3300704            Cabo Frio  2014    1  2014m01  Interior
# 27      3301876        Iguaba Grande  2014    1  2014m01  Interior
# ...         ...                  ...   ...  ...      ...       ...
# 12816   3301876        Iguaba Grande  2025    8  2025m08  Interior
# 12855   3304524       Rio das Ostras  2025    8  2025m08  Interior
# 12866   3305208  São Pedro da Aldeia  2025    8  2025m08  Interior
# 12869   3305505            Saquarema  2025    8  2025m08  Interior
# 12871   3305604         Silva Jardim  2025    8  2025m08  Interior
#
#        hom_doloso  lesao_corp_morte  latrocinio  cvli  ...  cmba  ameaca  \
# 2               2                 0           0     2  ...     0      91
# 4               2                 0           0     2  ...     2      46
# 5               0                 0           0     0  ...     0      26
# 11              9                 0           0     9  ...     0     121
# 27              0                 0           0     0  ...     0      19
# ...           ...               ...         ...   ...  ...   ...     ...
# 12816           0                 0           0     0  ...     0      18
# 12855           1                 0           0     1  ...     3      50
# 12866           3                 0           0     3  ...     1      33
# 12869           3                 0           0     3  ...     0      80
# 12871           0                 0           0     0  ...     0      13
#
#        pessoas_desaparecidas  encontro_cadaver  encontro_ossada  \
# 2                         10                 1                0
# 4                          0                 0                0
# 5                          0                 0                0
# 11                         7                 3                0
# 27                         0                 0                0
# ...                      ...               ...              ...
# 12816                      1                 0                0
# 12855                      8                 0                0
# 12866                      1                 0                0
# 12869                      2                 0                0
# 12871                      0                 0                0
#
#        pol_militares_mortos_serv  pol_civis_mortos_serv  registro_ocorrencias  \
# 2                              0                      0                   480
# 4                              0                      0                   309
# 5                              0                      0                   176
# 11                             0                      0                  1105
# 27                             0                      0                   126
# ...                          ...                    ...                   ...
# 12816                          0                      0                   157
# 12855                          0                      0                   724
# 12866                          0                      0                   321
# 12869                          0                      0                   858
# 12871                          0                      0                    68
#
#        fase  crimes_violentos
# 2         3                88
# 4         3                56
# 5         3                34
# 11        3               167
# 27        3                25
# ...     ...               ...
# 12816     2                18
# 12855     2                47
# 12866     2                39
# 12869     2                54
# 12871     2                15
#
# [1260 rows x 61 columns]

# %%
crimes_v = crimes_violentos.groupby('fmun')['crimes_violentos'].sum().reset_index()   
crimes_v
# Out:
#                   fmun  crimes_violentos
# 0             Araruama              9284
# 1   Armação dos Búzios              3676
# 2      Arraial do Cabo              2845
# 3            Cabo Frio             16239
# 4        Iguaba Grande              2006
# 5       Rio das Ostras             10859
# 6            Saquarema              7004
# 7         Silva Jardim              1660
# 8  São Pedro da Aldeia              6240

# %%
crimes_violentos_array = np.array(crimes_v['crimes_violentos'])

# %%
mediana_c = np.median(crimes_violentos_array)
media_c = np.mean(crimes_violentos_array)
q1_c = np.percentile(crimes_violentos_array, 25)
q2_c = np.percentile(crimes_violentos_array, 50)
q3_c = np.percentile (crimes_violentos_array, 75)
distancia_c = (media_c - mediana_c)/mediana_c
iqr_c = q3_c - q1_c
limite_superior_c = q3_c + (1.5 * iqr_c)
limite_inferior_c = q1_c - (1.5 * iqr_c)
print(f'Média: {media_c}')
print(f'Mediana: {mediana_c}')
print(f'Distância: {round(distancia_c*100,2)} %')
print(f'Limite Superior: {limite_superior_c}')
print(f'Limite Inferior: {limite_inferior_c}')
print(f'Q3: {q3_c}')
# Out:
# Média: 6645.888888888889
# Mediana: 6240.0
# Distância: 6.5 %
# Limite Superior: 18942.5
# Limite Inferior: -6813.5
# Q3: 9284.0

# %%
crimes_violentos_outliers = crimes_v.loc[crimes_v['crimes_violentos'] >= limite_superior]
crimes_violentos_outliers.sort_values(by="crimes_violentos", ascending=False)
# Out:
#                   fmun  crimes_violentos
# 3            Cabo Frio             16239
# 5       Rio das Ostras             10859
# 0             Araruama              9284
# 6            Saquarema              7004
# 8  São Pedro da Aldeia              6240

# %%
crimes_violentos_outliers.to_csv('crimes_violentos', index=False)
