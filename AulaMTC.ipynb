# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('funcionarios_dados_ti.csv', sep= ';')
df
# Out:
#                  Nome                             Cargo  Salario  Unnamed: 3  \
# 0           Ana Souza                Cientista de Dados    12000         NaN
# 1          Bruno Lima               Engenheiro de Dados    11500         NaN
# 2        Carla Mendes                    Analista de BI    10500         NaN
# 3        Daniel Rocha    Engenheiro de Machine Learning    13000         NaN
# 4       Elisa Martins                 Analista de Dados     9800         NaN
# 5      Felipe Andrade                Arquiteto de Dados    13500         NaN
# 6     Gabriela Torres               Engenheira de Dados    11800         NaN
# 7      Henrique Silva        Cientista de Dados JÃºnior    10200         NaN
# 8    Isabela Ferreira              Analista de BI Pleno    10800         NaN
# 9   JoÃ£o Pedro Ramos       Engenheiro de Dados SÃªnior    14000         NaN
# 10    Karina Oliveira          Especialista em Big Data    12500         NaN
# 11      Lucas Almeida         Analista de Dados JÃºnior     9700         NaN
# 12      Mariana Costa          Cientista de Dados Pleno    11000         NaN
# 13      Nelson Barros       Engenheiro de Dados JÃºnior    10100         NaN
# 14  Olivia Nascimento            Analista de BI SÃªnior    10900         NaN
# 15     Paulo Henrique  Arquiteto de SoluÃ§Ãµes de Dados    13200         NaN
# 16     QuÃ©sia Duarte        Cientista de Dados SÃªnior    14500         NaN
# 17    Rafael Teixeira         Engenheiro de Dados Pleno    11900         NaN
# 18      Sabrina Lopes           Analista de Dados Pleno     9900         NaN
# 19      Tiago Moreira             Especialista em Dados    12700         NaN
#
#     Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0          NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN
# 17         NaN         NaN         NaN         NaN
# 18         NaN         NaN         NaN         NaN
# 19         NaN         NaN         NaN         NaN

# %%
df

# %%
salario_array = np.array(df["Salario"])

# %%
mediana = np.median(salario_array)
media = np.mean(salario_array)
q1 = np.percentile(salario_array, 25)
q2 = np.percentile(salario_array, 50)
q3 = np.percentile (salario_array, 75)
distancia = (media - mediana)/mediana
print(f'Média: {media}')
print(f'Mediana: {mediana}')
print(f'Distância: {round(distancia*100,2)} %')
# Out:
# Média: 11675.0
# Mediana: 11650.0
# Distância: 0.21 %

# %% [markdown]
# Atividade prática 1
# Qual delegacia destoa das demais no que diz respeito a ocorrências relacionadas a furto e roubo de veículos na Capital?

# %%
ocorrencias = pd.read_csv('BaseDPEvolucaoMensalCisp.csv', sep= ';', encoding= 'latin1')
ocorrencias
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp                 munic    mcirc  \
# 0         1    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 1         4    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 2         5    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 3         6    1  2003  2003m01     1     1        Rio de Janeiro  3304557
# 4         7    1  2003  2003m01     1     1        Rio de Janeiro  3304557
# ...     ...  ...   ...      ...   ...   ...                   ...      ...
# 36487   159    7  2025  2025m07    35     4  Cachoeiras de Macacu  3300803
# 36488   165    7  2025  2025m07    33     5           Mangaratiba  3302601
# 36489   166    7  2025  2025m07    33     5        Angra dos Reis  3300100
# 36490   167    7  2025  2025m07    43     5                Paraty  3303807
# 36491   168    7  2025  2025m07    28     5             Rio Claro  3304409
#
#          regiao  hom_doloso  ...  cmp  cmba  ameaca  pessoas_desaparecidas  \
# 0       Capital           0  ...  NaN   NaN      21                      2
# 1       Capital           3  ...  NaN   NaN      15                      6
# 2       Capital           3  ...  NaN   NaN      47                      2
# 3       Capital           6  ...  NaN   NaN      26                      2
# 4       Capital           4  ...  NaN   NaN      10                      1
# ...         ...         ...  ...  ...   ...     ...                    ...
# 36487  Interior           1  ...  2.0   2.0      17                      0
# 36488  Interior           0  ...  8.0   0.0      31                      3
# 36489  Interior           1  ...  6.0   1.0      59                      7
# 36490  Interior           0  ...  8.0   0.0      18                      3
# 36491  Interior           0  ...  3.0   0.0      14                      0
#
#        encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 0                     0                0                          0
# 1                     0                1                          0
# 2                     1                0                          0
# 3                     1                0                          0
# 4                     3                0                          0
# ...                 ...              ...                        ...
# 36487                 0                0                          0
# 36488                 0                0                          0
# 36489                 0                0                          0
# 36490                 1                0                          0
# 36491                 0                0                          0
#
#        pol_civis_mortos_serv  registro_ocorrencias  fase
# 0                          0                   578     3
# 1                          0                   441     3
# 2                          0                   637     3
# 3                          0                   473     3
# 4                          0                   147     3
# ...                      ...                   ...   ...
# 36487                      0                   134     2
# 36488                      0                   207     2
# 36489                      0                   584     2
# 36490                      0                   187     2
# 36491                      0                    56     2
#
# [36492 rows x 63 columns]

# %%
ocorrencias_capital = ocorrencias.loc[ocorrencias['regiao']== 'Capital']
ocorrencias_capital.sort_values(by="regiao")
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 0         1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 24292     6    3  2018  2018m03     4     1  Rio de Janeiro  3304557  Capital
# 24293     7    3  2018  2018m03     5     1  Rio de Janeiro  3304557  Capital
# 24294     9    3  2018  2018m03     2     1  Rio de Janeiro  3304557  Capital
# 24295    10    3  2018  2018m03     2     1  Rio de Janeiro  3304557  Capital
# ...     ...  ...   ...      ...   ...   ...             ...      ...      ...
# 12114    27   10  2010  2010m10     9     2  Rio de Janeiro  3304557  Capital
# 12115    28   10  2010  2010m10     9     2  Rio de Janeiro  3304557  Capital
# 12116    29   10  2010  2010m10     9     2  Rio de Janeiro  3304557  Capital
# 12108    21   10  2010  2010m10    22     1  Rio de Janeiro  3304557  Capital
# 36395    44    7  2025  2025m07     3     1  Rio de Janeiro  3304557  Capital
#
#        hom_doloso  ...   cmp  cmba  ameaca  pessoas_desaparecidas  \
# 0               0  ...   NaN   NaN      21                      2
# 24292           3  ...   5.0   2.0      27                      2
# 24293           2  ...   4.0   0.0       8                      1
# 24294           2  ...  14.0   4.0      33                      2
# 24295           1  ...   6.0   0.0      25                      1
# ...           ...  ...   ...   ...     ...                    ...
# 12114           3  ...   3.0   0.0      78                      3
# 12115           7  ...   3.0   0.0      60                      4
# 12116           8  ...   2.0   0.0      38                      5
# 12108           6  ...  11.0   0.0      32                     12
# 36395           1  ...   5.0   4.0      27                      2
#
#        encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 0                     0                0                          0
# 24292                 0                0                          0
# 24293                 0                0                          0
# 24294                 0                0                          0
# 24295                 0                0                          0
# ...                 ...              ...                        ...
# 12114                 0                0                          0
# 12115                 0                0                          0
# 12116                 0                0                          0
# 12108                 0                0                          0
# 36395                 0                0                          0
#
#        pol_civis_mortos_serv  registro_ocorrencias  fase
# 0                          0                   578     3
# 24292                      0                   590     3
# 24293                      0                   235     3
# 24294                      0                   901     3
# 24295                      0                   817     3
# ...                      ...                   ...   ...
# 12114                      0                   847     3
# 12115                      0                   577     3
# 12116                      0                   715     3
# 12108                      0                   809     3
# 36395                      0                   829     2
#
# [10951 rows x 63 columns]

# %%
ocorrencias_capital['oc_veiculos'] = ocorrencias_capital['roubo_veiculo'] + ocorrencias_capital['furto_veiculos']
ocorrencias_capital
# Out:
# C:\Users\Steffani.Oliveira\AppData\Local\Temp\ipykernel_78052\1616238293.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ocorrencias_capital['oc_veiculos'] = ocorrencias_capital['roubo_veiculo'] + ocorrencias_capital['furto_veiculos']
#        cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 0         1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 1         4    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 2         5    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 3         6    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# 4         7    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# ...     ...  ...   ...      ...   ...   ...             ...      ...      ...
# 36391    40    7  2025  2025m07     9     2  Rio de Janeiro  3304557  Capital
# 36392    41    7  2025  2025m07    18     2  Rio de Janeiro  3304557  Capital
# 36393    42    7  2025  2025m07    31     2  Rio de Janeiro  3304557  Capital
# 36394    43    7  2025  2025m07    27     2  Rio de Janeiro  3304557  Capital
# 36395    44    7  2025  2025m07     3     1  Rio de Janeiro  3304557  Capital
#
#        hom_doloso  ...  ameaca  pessoas_desaparecidas  encontro_cadaver  \
# 0               0  ...      21                      2                 0
# 1               3  ...      15                      6                 0
# 2               3  ...      47                      2                 1
# 3               6  ...      26                      2                 1
# 4               4  ...      10                      1                 3
# ...           ...  ...     ...                    ...               ...
# 36391           3  ...      25                      2                 0
# 36392           1  ...      38                      8                 0
# 36393           0  ...      75                      2                 0
# 36394           0  ...      86                      9                 1
# 36395           1  ...      27                      2                 0
#
#        encontro_ossada  pol_militares_mortos_serv  pol_civis_mortos_serv  \
# 0                    0                          0                      0
# 1                    1                          0                      0
# 2                    0                          0                      0
# 3                    0                          0                      0
# 4                    0                          0                      0
# ...                ...                        ...                    ...
# 36391                0                          0                      0
# 36392                0                          0                      0
# 36393                0                          0                      0
# 36394                0                          0                      0
# 36395                0                          0                      0
#
#        registro_ocorrencias  fase  soma  oc_veiculos
# 0                       578     3    17           17
# 1                       441     3    18           18
# 2                       637     3    39           39
# 3                       473     3    44           44
# 4                       147     3    35           35
# ...                     ...   ...   ...          ...
# 36391                   598     2    72           72
# 36392                   786     2    17           17
# 36393                  1384     2    41           41
# 36394                   671     2    23           23
# 36395                   829     2    51           51
#
# [10951 rows x 65 columns]

# %%
ocorrencias_veiculos = ocorrencias_capital.groupby('cisp')['oc_veiculos'].sum().reset_index()   
ocorrencias_veiculos
# Out:
#     cisp  oc_veiculos
# 0      1         2487
# 1      4         3364
# 2      5         4297
# 3      6         6732
# 4      7         3910
# 5      9        12636
# 6     10         9615
# 7     11          179
# 8     12         2365
# 9     13         1466
# 10    14         3460
# 11    15         3060
# 12    16        18043
# 13    17        11163
# 14    18        11143
# 15    19        10111
# 16    20        13177
# 17    21        25101
# 18    22        22756
# 19    23        15172
# 20    24        14372
# 21    25        12602
# 22    26        10318
# 23    27        38630
# 24    28        14334
# 25    29        21314
# 26    30        17629
# 27    31        17424
# 28    32        13616
# 29    33        25677
# 30    34        36695
# 31    35        33062
# 32    36         9988
# 33    37        12866
# 34    38        25775
# 35    39        32183
# 36    40        22188
# 37    41        10098
# 38    42         9917
# 39    43         4378
# 40    44        17013
# 41    45           78

# %%
oc_veiculos_array = np.array(ocorrencias_veiculos["oc_veiculos"])

# %%
mediana = np.median(oc_veiculos_array)
media = np.mean(oc_veiculos_array)
q1 = np.percentile(oc_veiculos_array, 25)
q2 = np.percentile(oc_veiculos_array, 50)
q3 = np.percentile (oc_veiculos_array, 75)
distancia = (media - mediana)/mediana
iqr = q3 - q1
limite_superior = q3 + (1.5 * iqr)
limite_inferior = q1 - (1.5 * iqr)
print(f'Média: {media}')
print(f'Mediana: {mediana}')
print(f'Distância: {round(distancia*100,2)} %')
# Out:
# Média: 13818.904761904761
# Mediana: 12619.0
# Distância: 9.51 %

# %%
veiculos_outliers = ocorrencias_veiculos.loc[ocorrencias_veiculos['oc_veiculos'] >= limite_superior]
veiculos_outliers.sort_values(by="oc_veiculos", ascending= False)
# Out:
#     cisp  oc_veiculos
# 23    27        38630

# %% [markdown]
# Atividade prática 2
# Na última década, algum município da região metropolitana pode ser considerado outlier sobre as ocorrências de furto de veículos?

# %%
ocorrencias1 = pd.read_csv('https://www.ispdados.rj.gov.br/Arquivos/BaseMunicipioTaxaAno.csv', sep= ';', encoding= 'latin1')
ocorrencias1
# Out:
#      fmun_cod            fmun   ano    regiao hom_doloso lesao_corp_morte  \
# 0     3300100  Angra dos Reis  2014  Interior      40,55                0
# 1     3300100  Angra dos Reis  2015  Interior      48,86                0
# 2     3300100  Angra dos Reis  2016  Interior      44,39             0,52
# 3     3300100  Angra dos Reis  2017  Interior       44,7                0
# 4     3300100  Angra dos Reis  2018  Interior      65,87                0
# ..        ...             ...   ...       ...        ...              ...
# 639   3306305   Volta Redonda  2016  Interior      24,65                0
# 640   3306305   Volta Redonda  2017  Interior      23,76                0
# 641   3306305   Volta Redonda  2018  Interior      26,47             0,37
# 642   3306305   Volta Redonda  2019  Interior       32,6             0,37
# 643   3306305   Volta Redonda  2020  Interior      25,55                0
#
#     latrocinio   cvli hom_por_interv_policial letalidade_violenta  ...  \
# 0         0,54  41,09                    1,08               42,18  ...
# 1            0  48,86                     6,9               55,77  ...
# 2         0,52  45,43                    3,66               49,09  ...
# 3            0   44,7                   13,36               58,06  ...
# 4          0,5  66,36                   25,45               91,81  ...
# ..         ...    ...                     ...                 ...  ...
# 639          0  24,65                    1,52               26,17  ...
# 640       0,38  24,13                    0,75               24,89  ...
# 641       0,74  27,57                    2,94               30,51  ...
# 642          0  32,97                     3,3               36,26  ...
# 643       0,36  25,91                    5,11               31,02  ...
#
#         cmp  cmba  ameaca pessoas_desaparecidas encontro_cadaver  \
# 0      87,6  2,16  510,44                 49,75             4,33
# 1     77,55  3,19  477,49                  39,3             1,59
# 2     65,27  7,31  341,51                 40,21              4,7
# 3    101,22  2,57  230,71                 27,75             3,08
# 4     84,33  6,49  221,05                 25,95             5,99
# ..      ...   ...     ...                   ...              ...
# 639   87,23  6,83  348,56                 17,07             4,93
# 640   87,86  5,66  243,21                 14,33             3,02
# 641   85,29  1,84  303,68                 13,97             1,84
# 642   91,94   2,2  318,67                  34,8              1,1
# 643   78,84  0,73   302,2                 22,63             1,09
#
#     encontro_ossada pol_militares_mortos_serv pol_civis_mortos_serv  \
# 0                 0                         0                     0
# 1                 0                         0                     0
# 2                 0                         0                     0
# 3              0,51                         0                     0
# 4               0,5                      2,22                     0
# ..              ...                       ...                   ...
# 639               0                         0                     0
# 640               0                         0                     0
# 641               0                         0                     0
# 642            0,37                      2,26                     0
# 643               0                      2,26                     0
#
#     registro_ocorrencias fase
# 0                3256,19    3
# 1                3037,56    3
# 2                2858,43    3
# 3                2321,97    3
# 4                2292,83    3
# ..                   ...  ...
# 639              3021,33    3
# 640              2459,27    3
# 641              2638,62    3
# 642              2974,96    3
# 643               2798,3    3
#
# [644 rows x 57 columns]

# %%
furto_veiculos = ocorrencias1.groupby('fmun')['furto_veiculos'].sum().reset_index()   
furto_veiculos
# Out:
#                   fmun                              furto_veiculos
# 0       Angra dos Reis    283,18281,18306,43201,79171,28132,7868,4
# 1              Aperibé                                     -------
# 2             Araruama   322,98311,57221,8167,33189,07185,26195,24
# 3                Areal                                     -------
# 4   Armação dos Búzios                                     -------
# ..                 ...                                         ...
# 87           Três Rios      134,88223,62140,23113,8105,2888,450,87
# 88             Valença        113,0557,3184,6965,6375,7542,1569,92
# 89           Varre-Sai                                     -------
# 90           Vassouras                                     -------
# 91       Volta Redonda  176,53176,68193,42153,54189,19186,09150,55
#
# [92 rows x 2 columns]

# %%
furto_veiculos_array = np.array(furto_veiculos["furto_veiculos"])

# %%
mediana = np.median(furto_veiculos_array)
media = np.mean(furto_veiculos_array)
q1 = np.percentile(furto_veiculos_array, 25)
q2 = np.percentile(furto_veiculos_array, 50)
q3 = np.percentile (furto_veiculos_array, 75)
distancia = (media - mediana)/mediana
iqr = q3 - q1
limite_superior = q3 + (1.5 * iqr)
limite_inferior = q1 - (1.5 * iqr)
print(f'Média: {media}')
print(f'Mediana: {mediana}')
print(f'Distância: {round(distancia*100,2)} %')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 mediana = np.median(furto_veiculos_array)
#       2 media = np.mean(furto_veiculos_array)
#       3 q1 = np.percentile(furto_veiculos_array, 25)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numpy\lib\_function_base_impl.py:4021, in median(a, axis, out, overwrite_input, keepdims)
#    3936 @array_function_dispatch(_median_dispatcher)
#    3937 def median(a, axis=None, out=None, overwrite_input=False, keepdims=False):
#    3938     """
#    3939     Compute the median along the specified axis.
#    3940
#    (...)   4019
#    4020     """
# -> 4021     return _ureduce(a, func=_median, keepdims=keepdims, axis=axis, out=out,
#    4022                     overwrite_input=overwrite_input)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numpy\lib\_function_base_impl.py:3914, in _ureduce(a, func, keepdims, **kwargs)
#    3911     index_out = (0, ) * nd
#    3912     kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3914 r = func(a, **kwargs)
#    3916 if out is not None:
#    3917     return out
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numpy\lib\_function_base_impl.py:4073, in _median(a, axis, out, overwrite_input)
#    4069 indexer = tuple(indexer)
#    4071 # Use mean in both odd and even case to coerce data type,
#    4072 # using out array if needed.
# -> 4073 rout = mean(part[indexer], axis=axis, out=out)
#    4074 if supports_nans and sz > 0:
#    4075     # If nans are possible, warn and replace by nans like mean would.
#    4076     rout = np.lib._utils_impl._median_nancheck(part, rout, axis)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numpy\_core\fromnumeric.py:3860, in mean(a, axis, dtype, out, keepdims, where)
#    3857     else:
#    3858         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3860 return _methods._mean(a, axis=axis, dtype=dtype,
#    3861                       out=out, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numpy\_core\_methods.py:146, in _mean(a, axis, dtype, out, keepdims, where)
#     144         ret = ret.dtype.type(ret / rcount)
#     145 else:
# --> 146     ret = ret / rcount
#     148 return ret
#
# TypeError: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
