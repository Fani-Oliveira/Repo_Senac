# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.DataFrame({'investimento_marketing': [10, 20, 30, 40, 50, 60],
                   'vendas': [100, 130, 160, 180, 210, 240]})


x = df[['investimento_marketing']]
y = df['vendas']

#Treinar o modelo
modelo = LinearRegression()
modelo.fit(x,y)

#Estender os dados para previsão
X_extendido = pd.DataFrame({'investimento_marketing': [10, 20, 30, 40, 50, 60, 70, 80, 100]})
y_pred = modelo.predict(X_extendido)

#Visualizar
plt.figure(figsize=(8, 5))
plt.scatter(df['investimento_marketing'], df['vendas'], color='green')
plt.plot(X_extendido['investimento_marketing'], y_pred, color='orange')
plt.xlabel('Investimento em Marketing (mil R$)')
plt.ylabel('Vendas (mil unidades)')
plt.title('Regressão Linear com Previsão até R$110 mil')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df = pd.DataFrame({'investimento_marketing': [10, 20, 30, 40, 50, 60],
                   'vendas': [100, 10, 250, 50, 500, 30]})


x = df[['investimento_marketing']]
y = df['vendas']

#Treinar o modelo
modelo = LinearRegression()
modelo.fit(x,y)

#Estender os dados para previsão
X_extendido = pd.DataFrame({'investimento_marketing': [70, 80, 100]})
y_pred = modelo.predict(X_extendido)

#Visualizar
plt.figure(figsize=(8, 5))
plt.scatter(df['investimento_marketing'], df['vendas'], color='green')
plt.plot(X_extendido['investimento_marketing'], y_pred, color='orange')
plt.xlabel('Investimento em Marketing (mil R$)')
plt.ylabel('Vendas (mil unidades)')
plt.title('Regressão Linear com Previsão até R$110 mil')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
